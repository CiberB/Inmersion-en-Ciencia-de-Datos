# %% [markdown]
# <a href="https://colab.research.google.com/github/CiberB/Inmersion-en-Ciencia-de-Datos/blob/main/Mi_Primer_Proyecto_en_Ciencia_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvenidos, aqui empieza mi viaje en ciencia de datos

# %% [markdown]
# # CLASE NUMERO 1

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

inmuebles = pd.read_csv ("/content/drive/MyDrive/Ciencia de Datos/inmuebles.csv")
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental
# 1         Casa                   Casa en venta en Castilla
# 2  Apartamento     Apartamento en venta en Chico Reservado
# 3  Apartamento             Apartamento en venta en Usaquén
# 4  Apartamento         Apartamento en venta en Bella Suiza
#
#                                         Localizacion  \
# 0       Zona Noroccidental, Bogotá D.C, Cundinamarca
# 1  Castilla, Kennedy, Zona Suroccidental, Bogotá ...
# 2  Chico Reservado, Chapinero, Zona Chapinero, Bo...
# 3      Usaquén, Zona Norte, Bogotá D.C, Cundinamarca
# 4  Bella Suiza, Usaquén, Zona Norte, Bogotá D.C, ...
#
#                            Atributos            Valor
# 0         3 habitaciones2 baños70 m²    $ 360.000.000
# 1        4 habitaciones3 baños170 m²    $ 670.000.000
# 2  3 habitaciones3 baños144 / 144 m²  $ 1.120.000.000
# 3  3 habitaciones2 baños154 / 134 m²    $ 890.000.000
# ...

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Localizacion', 'Atributos', 'Valor'], dtype='object')

# %%
columnas = {"costo":"Lukas","Área":"Area" }
inmuebles= inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  \
# 8696  Apartamento       Apartamento en venta en Chapinero
# 230   Apartamento        Apartamento en venta en Cedritos
# 2290  Apartamento    Apartamento en venta en Buenos Aires
# 6378  Apartamento         Apartamento en venta en Usaquén
# 4416         Casa                   Casa en venta en Suba
# 3944  Apartamento   Apartamento en venta en Santa Barbara
# 5114  Apartamento  Apartamento en venta en Chapinero Alto
# 3815  Apartamento         Apartamento en venta en Mazuren
# 1888         Casa              Casa en venta en Chapinero
# 2878  Apartamento            Apartamento en venta en Bosa
#
#                                            Localizacion  \
# 8696  Chapinero, Zona Chapinero, Bogotá D.C, Cundina...
# 230   Cedritos, Usaquén, Zona Norte, Bogotá D.C, Cun...
# 2290  Buenos Aires, Ciudad Bolívar, Zona Sur, Bogotá...
# 6378      Usaquén, Zona Norte, Bogotá D.C, Cundinamarca
# ...

# %%
inmuebles = pd.read_csv ("/content/drive/MyDrive/Ciencia de Datos/inmuebles_bogota.csv")
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
columnas = {"Valor":"Lukas","Área":"Area", "Baños":"Banos" }
inmuebles= inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1830         Casa                    Casa en venta en Kennedy             3
# 2979         Casa                   Casa en venta en Engativa             3
# 8311  Apartamento      Apartamento en venta en Antonio Nariño             2
# 6368  Apartamento            Apartamento en venta en El Chicó             1
# 8857  Apartamento             Apartamento en venta en Kennedy             3
# 2676  Apartamento     Apartamento en venta en Chico Reservado             1
# 42    Apartamento  Apartamento en venta en Zona Noroccidental             4
# 7451         Casa              Casa en venta en Puente Aranda             6
# 7262  Apartamento             Apartamento en venta en Usaquén             3
# 5751  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio  \
# 1830      2    57             Kennedy
# 2979      3    92            Engativa
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Lukas         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc [1500]
# Out:
# Tipo                                   Apartamento
# Descripcion      Apartamento en venta en Chapinero
# Habitaciones                                     1
# Banos                                            1
# Area                                            39
# Barrio                                   Chapinero
# UPZ             CHAPINERO: Pardo Rubio + Chapinero
# Lukas                                $ 270.000.000
# Name: 1500, dtype: object

# %%
inmuebles.iloc [1500:1700]
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 1500  Apartamento    Apartamento en venta en Chapinero             1      1
# 1501  Apartamento  Apartamento en venta en Bella Suiza             1      2
# 1502  Apartamento    Apartamento en venta en Chapinero             3      2
# 1503  Apartamento     Apartamento en venta en Cedritos             3      3
# 1504         Casa                Casa en venta en Suba             3      2
# ...           ...                                  ...           ...    ...
# 1695  Apartamento      Apartamento en venta en Usaquén             3      2
# 1696  Apartamento     Apartamento en venta en Fontibón             3      2
# 1697         Casa             Casa en venta en Usaquén             3      3
# 1698  Apartamento     Apartamento en venta en Hayuelos             3      2
# 1699        Local     Local en venta en Barrios Unidos            13      8
#
# ...

# %%
inmuebles.iloc [9515:9519]
# Out:
#              Tipo                                     Descripcion  \
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
#
#       Habitaciones  Banos  Area                  Barrio  \
# 9515             3      2    70                 Kennedy
# 9516             2      2   100  Parque Central Bavaria
# 9517             8      6   383                Restrepo
# 9518             3      2   183                Engativa
#
#                                          UPZ          Lukas
# 9515                         Kennedy Central  $ 290.000.000
# 9516  SANTA FE: Las Nieves + Sagrado Corazón  $ 670.000.000
# 9517                                Restrepo  $ 900.000.000
# 9518                                Engativá  $ 335.000.000

# %%
inmuebles ["Lukas"][1502]
# Out:
# '$ 900.000.000'

# %%
inmuebles ["Lukas"][1502:1648]
# Out:
# 1502    $ 900.000.000
# 1503    $ 490.000.000
# 1504    $ 380.000.000
# 1505    $ 660.000.000
# 1506    $ 850.000.000
#             ...
# 1643    $ 520.000.000
# 1644    $ 165.000.000
# 1645    $ 160.000.000
# 1646    $ 600.000.000
# 1647    $ 170.000.000
# Name: Lukas, Length: 146, dtype: object

# %%
inmuebles.Area.mean ()
# Out:
# 146.66470588235293

# %%
inmuebles.UPZ == "Restrepo"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517     True
# 9518    False
# 9519    False
# Name: UPZ, Length: 9520, dtype: bool

# %%
sum ((inmuebles.UPZ == "Restrepo"))
# Out:
# 58

# %%
inmuebles_UPZ_Restrepo = (inmuebles.UPZ == "Restrepo")
type(inmuebles_UPZ_Restrepo)
# Out:
# pandas.core.series.Series

# %%
UPZ_Restrepo = inmuebles[inmuebles_UPZ_Restrepo]
UPZ_Restrepo
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 267   Apartamento  Apartamento en venta en Antonio Nariño             2
# 376   Apartamento  Apartamento en venta en Antonio Nariño             2
# 461          Casa         Casa en venta en Antonio Nariño             5
# 559   Apartamento  Apartamento en venta en Antonio Nariño             3
# 661   Apartamento  Apartamento en venta en Antonio Nariño             3
# 732   Apartamento  Apartamento en venta en Antonio Nariño             3
# 1173  Apartamento  Apartamento en venta en Antonio Nariño             2
# 1214  Apartamento  Apartamento en venta en Antonio Nariño             3
# 1413  Apartamento  Apartamento en venta en Antonio Nariño             2
# 1691         Casa         Casa en venta en Antonio Nariño             5
# 2208         Casa         Casa en venta en Antonio Nariño             5
# 2427  Apartamento  Apartamento en venta en Antonio Nariño             4
# ...

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
UPZ_Restrepo.Area.mean()
# Out:
# 192.9655172413793

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebleS_UPZ = inmuebles.Barrio.value_counts()
inmuebleS_UPZ.plot.bar()
# Out:
# <Axes: >

# %%
inmuebleS_UPZ.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmuebleS_UPZ.head(10).plot.line()
# Out:
# <Axes: >

# %% [markdown]
# Tarea
#
# 1- Promedio de area de cada uno de los barrios del dataset el top 10
#
# 2- Investigar y usar otros comandos estadisticos, ejemplo conteo, media, valor minimo y maximo

# %% [markdown]
# Resuelto punto 1-

# %%
Barrios_agrupados = inmuebles.groupby("Barrio")["Area"].count().sort_values(ascending=False)

Barrios_agrupados.head(10)
# Out:
# Barrio
# Usaquén               1105
# Zona Noroccidental     877
# Kennedy                589
# Bosa                   589
# Cedritos               554
# Barrios Unidos         473
# Engativa               462
# Suba                   443
# Santa Barbara          438
# Chapinero              332
# Name: Area, dtype: int64

# %%
Barrios_agrupados.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
Areas_Barrio = inmuebles.groupby("Barrio")["Area"].mean().sort_values(ascending=False)
Areas_Barrio.head(10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
Areas_Barrio.head(10).plot.line()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.dtypes
# Out:
# Tipo            object
# Descripcion     object
# Habitaciones     int64
# Banos            int64
# Area             int64
# Barrio          object
# UPZ             object
# Lukas           object
# dtype: object

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles.dtypes
# Out:
# Tipo            object
# Descripcion     object
# Habitaciones     int64
# Banos            int64
# Area             int64
# Barrio          object
# UPZ             object
# Lukas           object
# dtype: object

# %%
inmuebles["Lukas"] = inmuebles["Lukas"].str.replace("\$","", regex=True)
inmuebles["Lukas"] = inmuebles["Lukas"].str.replace("\.","", regex=True)

# Agregar la condición para evitar que se convierta una cadena vacía a tipo int64
mask = inmuebles["Lukas"].eq('')
inmuebles.loc[mask, "Lukas"] = None
inmuebles["Lukas"] = inmuebles["Lukas"].astype("Int64")

# %%
inmuebles.dtypes
# Out:
# Tipo            object
# Descripcion     object
# Habitaciones     int64
# Banos            int64
# Area             int64
# Barrio          object
# UPZ             object
# Lukas            Int64
# dtype: object

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
Lukas_Barrio = inmuebles.groupby("Barrio")["Lukas"].mean().sort_values(ascending=False)
Lukas_Barrio.head(10)
# Out:
# Barrio
# Santa Ana               3172500000.0
# La Candelaria           1544228125.0
# El Retiro          1528421052.631579
# Los Rosales             1479646510.0
# Quinta Camacho     1449215772.952381
# El Chicó           1393410958.904109
# Cerros De Suba          1315000000.0
# Chico Navarra      1292083333.333333
# El Refugio              1231625000.0
# Chico Reservado    1157212618.093333
# Name: Lukas, dtype: Float64

# %%
Lukas_Barrio = inmuebles.groupby("Barrio")["Lukas"].min().sort_values(ascending=False)
Lukas_Barrio.head(10)
# Out:
# Barrio
# El Retiro                840000000
# Cerros De Suba           830000000
# Santa Ana                780000000
# Santa Maria Del Lago     640000000
# Bosque Popular           630000000
# Alameda                  580000000
# Gratamira                550000000
# Bellavista Occidental    550000000
# Las Ferias               550000000
# Quiroga                  550000000
# Name: Lukas, dtype: Int64

# %%
Lukas_Barrio = inmuebles.groupby("Barrio")["Lukas"].max().sort_values(ascending=False)
Lukas_Barrio.head(10)
# Out:
# Barrio
# Usaquén               16000000000
# El Chicó              13200000000
# La Candelaria         10451500000
# Santa Barbara          9200000000
# Santa Ana              8800000000
# Chapinero              8550000000
# Los Rosales            8358000000
# Zona Noroccidental     7200000000
# Las Nieves             7000000000
# San Patricio           7000000000
# Name: Lukas, dtype: Int64

# %% [markdown]
# # CLASE NUMERO 2

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8656         Casa                       Casa en venta en Bosa             2
# 3242  Apartamento  Apartamento en venta en Portales Del Norte             3
# 1368  Apartamento        Apartamento en venta en San Patricio             3
# 4387         Casa                Casa en venta en Teusaquillo             7
# 8122         Casa                    Casa en venta en Kennedy             6
#
#       Banos  Area              Barrio                                    UPZ  \
# 8656      1    62                Bosa                           Bosa Central
# 3242      2    86  Portales Del Norte                               Britalia
# 1368      4   133        San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 4387      3   310         Teusaquillo                            Teusaquillo
# 8122      4   298             Kennedy                        Kennedy Central
#
#            Lukas
# 8656   125000000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Lukas         9520 non-null   Int64
# dtypes: Int64(1), int64(3), object(4)
# memory usage: 604.4+ KB

# %%
inmuebles[["Barrio","Lukas"]]
# Out:
#                       Barrio       Lukas
# 0         Zona Noroccidental   360000000
# 1                   Castilla   670000000
# 2            Chico Reservado  1120000000
# 3                    Usaquén   890000000
# 4                Bella Suiza   970000000
# ...                      ...         ...
# 9515                 Kennedy   290000000
# 9516  Parque Central Bavaria   670000000
# 9517                Restrepo   900000000
# 9518                Engativa   335000000
# 9519                 Tintala   144990000
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Lukas         9520 non-null   Int64
# dtypes: Int64(1), int64(3), object(4)
# memory usage: 604.4+ KB

# %%
inmuebles["Precio_Millon"] = inmuebles.Lukas.astype("float")/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Lukas          9520 non-null   Int64
#  8   Precio_Millon  9520 non-null   float64
# dtypes: Int64(1), float64(1), int64(3), object(4)
# memory usage: 678.8+ KB

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5933  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 6400  Apartamento             Apartamento en venta en Usaquén             2
# 7148  Apartamento            Apartamento en venta en Fontibón             3
# 8998  Apartamento                Apartamento en venta en Suba             2
# 1370         Casa                    Casa en venta en Usaquén             8
#
#       Banos  Area              Barrio                                 UPZ  \
# 5933      2    88  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 6400      2    71             Usaquén                             Usaquén
# 7148      2   109            Fontibón                            Fontibón
# 8998      2    59                Suba                                Suba
# 1370      4   253             Usaquén                             Usaquén
#
#           Lukas  Precio_Millon
# 5933  500000000          500.0
# ...

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area         Lukas  Precio_Millon
# count   9520.000000  9520.000000    9520.000000  9.520000e+03    9520.000000
# mean       3.072479     2.447899     146.664706  6.020624e+08     602.062354
# std        2.049856     1.255314    1731.379622  7.046021e+08     704.602062
# min        1.000000     0.000000       2.000000  6.000000e+07      60.000000
# 25%        2.000000     2.000000      57.000000  2.500000e+08     250.000000
# 50%        3.000000     2.000000      80.000000  4.091825e+08     409.182500
# 75%        3.000000     3.000000     135.000000  6.800000e+08     680.000000
# max      110.000000     9.000000  166243.000000  1.600000e+10   16000.000000

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format",lambda x: "%.2f" % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area          Lukas  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00        9520.00
# mean           3.07    2.45    146.66   602062353.53         602.06
# std            2.05    1.26   1731.38   704602061.61         704.60
# min            1.00    0.00      2.00    60000000.00          60.00
# 25%            2.00    2.00     57.00   250000000.00         250.00
# 50%            3.00    2.00     80.00   409182500.00         409.18
# 75%            3.00    3.00    135.00   680000000.00         680.00
# max          110.00    9.00 166243.00 16000000000.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ      Lukas  Precio_Millon
# 897  Usaquén  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ      Lukas  Precio_Millon
# 8401     2  San Cristobal  Sosiego  180000000         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
sns.histplot(data=inmuebles, x="Precio_Millon")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(40,20))
sns.histplot(data=inmuebles, x="Precio_Millon")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon")
grafica.set_title("Distribucion de Valores Inmuebles Tabogo")
plt.xlim(50,1000)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon", kde=True,hue="Tipo")
grafica.set_title("Distribucion de Valores Inmuebles Tabogo")
plt.xlim(50,1000)

plt.savefig("/content/drive/MyDrive/Ciencia de Datos/Graficas/Grafica1.png", format="png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon", kde=True,hue="Tipo")
grafica.set_title("Distribucion de Valores Inmuebles Tabogo")
plt.xlim(50,1000)
plt.ylim(0,800)

plt.savefig("/content/drive/MyDrive/Ciencia de Datos/Graficas/Grafica2.png", format="png")
plt.show()

# %% [markdown]
# # Actividad
#
# 1- Estudiar histograma de valores, seleccionar 3 tipos de inmuebles (refinar grafico: Titulos, colores,Tamaño de letra, conclusion de la informacion)
#
# 2-Precio M2 por barrio y Hacer el grafico mas adecuado para esta nueva variable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
grafica = sns.histplot(data=inmuebles, x="Precio_Millon", kde=True,hue="Tipo")
grafica.set_title("Distribucion de Valores Inmuebles Tabogo")
plt.xlim(50,1000)
plt.ylim(0,800)

plt.savefig("/content/drive/MyDrive/Ciencia de Datos/Graficas/Grafica3.png", format="png")
plt.show()

# %% [markdown]
# # CLASE NUMERO 3

# %%
inmuebles ["Valor_M2"] = inmuebles["Precio_Millon"]/inmuebles["Area"]
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#         Lukas  Precio_Millon  Valor_M2
# 0   360000000         360.00      5.14
# ...

# %%
inmuebles.groupby("Barrio").mean()
# Out:
#                     Habitaciones  Banos   Area        Lukas  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00 580000000.00         580.00
# Alhambra                    3.00   2.94 190.41 752352941.18         752.35
# Andes Norte                 3.00   2.86 124.86 709571428.57         709.57
# Antonio Nariño              4.31   2.50 163.06 459221875.00         459.22
# Barrancas                   2.87   2.13  70.20 314133333.33         314.13
# ...                          ...    ...    ...          ...            ...
# Villa Maria                 4.69   3.69 207.15 402846153.85         402.85
# Villas De Granada           3.45   2.32  86.59 282301136.36         282.30
# Villemar                    2.94   2.06  76.89 303833333.33         303.83
# Zona Franca                 2.00   1.00  54.00 160000000.00         160.00
# Zona Noroccidental          3.17   2.51 135.79 620813068.88         620.81
#
#                     Valor_M2
# Barrio
# ...

# %%
datos_barrio= inmuebles.groupby("Barrio").sum()

datos_barrio
# Out:
#                     Habitaciones  Banos    Area         Lukas  Precio_Millon  \
# Barrio
# Alameda                        3      2      97     580000000         580.00
# Alhambra                      51     50    3237   12790000000       12790.00
# Andes Norte                   21     20     874    4967000000        4967.00
# Antonio Nariño               207    120    7827   22042650000       22042.65
# Barrancas                     43     32    1053    4712000000        4712.00
# ...                          ...    ...     ...           ...            ...
# Villa Maria                   61     48    2693    5237000000        5237.00
# Villas De Granada             76     51    1905    6210625000        6210.62
# Villemar                      53     37    1384    5469000000        5469.00
# Zona Franca                    2      1      54     160000000         160.00
# Zona Noroccidental          2778   2204  119084  544453061408      544453.06
#
#                     Valor_M2
# ...

# %%
datos_barrio["Valor_M2"] = datos_barrio["Precio_Millon"]/datos_barrio["Area"]

datos_barrio
# Out:
#                     Habitaciones  Banos    Area         Lukas  Precio_Millon  \
# Barrio
# Alameda                        3      2      97     580000000         580.00
# Alhambra                      51     50    3237   12790000000       12790.00
# Andes Norte                   21     20     874    4967000000        4967.00
# Antonio Nariño               207    120    7827   22042650000       22042.65
# Barrancas                     43     32    1053    4712000000        4712.00
# ...                          ...    ...     ...           ...            ...
# Villa Maria                   61     48    2693    5237000000        5237.00
# Villas De Granada             76     51    1905    6210625000        6210.62
# Villemar                      53     37    1384    5469000000        5469.00
# Zona Franca                    2      1      54     160000000         160.00
# Zona Noroccidental          2778   2204  119084  544453061408      544453.06
#
#                     Valor_M2
# ...

# %%
M2_Barrio = dict(datos_barrio["Valor_M2"])

# %%
inmuebles["Valor_M2"] = inmuebles["Barrio"]
inmuebles["Valor_M2"] = inmuebles["Valor_M2"].map(M2_Barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#         Lukas  Precio_Millon  Valor_M2
# 0   360000000         360.00      4.57
# ...

# %%
Top_Barrios = inmuebles["Barrio"].value_counts()[:10].index

# %%
datos_barrio
# Out:
#                     Habitaciones  Banos    Area         Lukas  Precio_Millon  \
# Barrio
# Alameda                        3      2      97     580000000         580.00
# Alhambra                      51     50    3237   12790000000       12790.00
# Andes Norte                   21     20     874    4967000000        4967.00
# Antonio Nariño               207    120    7827   22042650000       22042.65
# Barrancas                     43     32    1053    4712000000        4712.00
# ...                          ...    ...     ...           ...            ...
# Villa Maria                   61     48    2693    5237000000        5237.00
# Villas De Granada             76     51    1905    6210625000        6210.62
# Villemar                      53     37    1384    5469000000        5469.00
# Zona Franca                    2      1      54     160000000         160.00
# Zona Noroccidental          2778   2204  119084  544453061408      544453.06
#
#                     Valor_M2
# ...

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area         Lukas  \
# 0               Alameda             3      2      97     580000000
# 1              Alhambra            51     50    3237   12790000000
# 2           Andes Norte            21     20     874    4967000000
# 3        Antonio Nariño           207    120    7827   22042650000
# 4             Barrancas            43     32    1053    4712000000
# ..                  ...           ...    ...     ...           ...
# 144         Villa Maria            61     48    2693    5237000000
# 145   Villas De Granada            76     51    1905    6210625000
# 146            Villemar            53     37    1384    5469000000
# 147         Zona Franca             2      1      54     160000000
# 148  Zona Noroccidental          2778   2204  119084  544453061408
#
#      Precio_Millon  Valor_M2
# 0           580.00      5.98
# 1         12790.00      3.95
# 2          4967.00      5.68
# 3         22042.65      2.82
# ...

# %%
datos_barrio.query("Barrio in @Top_Barrios")
# Out:
#                  Barrio  Habitaciones  Banos    Area         Lukas  \
# 5        Barrios Unidos          1525   1196   87799  259877762703
# 10                 Bosa          1743    789   34879   93400560494
# 22             Cedritos          1458   1348   53711  270027733421
# 24            Chapinero           892    913   81248  372130933118
# 50             Engativa          1676   1077   59808  172711728232
# 63              Kennedy          2151   1233   61475  207963648911
# 125       Santa Barbara          1073   1162   54693  320097803000
# 132                Suba          1497   1202   61615  266406040022
# 138             Usaquén          3109   3044  148121  837710365000
# 148  Zona Noroccidental          2778   2204  119084  544453061408
#
#      Precio_Millon  Valor_M2
# 5        259877.76      2.96
# 10        93400.56      2.68
# 22       270027.73      5.03
# 24       372130.93      4.58
# 50       172711.73      2.89
# 63       207963.65      3.38
# ...

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x="Barrio",y="Valor_M2", data = datos_barrio.query("Barrio in @Top_Barrios"))
ax.tick_params(axis="x", rotation=300)
ax.tick_params(axis="y", rotation=80)

# %%
plt.figure(figsize=(10,10))
ax=sns.boxplot(x="Barrio",y="Precio_Millon", data = inmuebles.query("Barrio in @Top_Barrios"))
ax.tick_params(axis="x", rotation=300)
ax.tick_params(axis="y", rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax=sns.boxplot(x="Barrio",y="Valor_M2", data = inmuebles.query("Barrio in @Top_Barrios"))
ax.tick_params(axis="x", rotation=300)

plt.show()

# %%
inmuebles.dtypes
# Out:
# Tipo              object
# Descripcion       object
# Habitaciones       int64
# Banos              int64
# Area               int64
# Barrio            object
# UPZ               object
# Lukas              Int64
# Precio_Millon    float64
# Valor_M2         float64
# dtype: object

# %%
plt.figure(figsize=(10,10))
ax=sns.boxplot(x="Barrio",y="Precio_Millon", data = inmuebles.query("Barrio in @Top_Barrios & Precio_Millon < 8000" ))
ax.tick_params(axis="x", rotation=300)
ax.tick_params(axis="y", rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,10))
ax=sns.boxplot(x="Barrio",y="Area", data = inmuebles.query("Barrio in @Top_Barrios & Area <500 " ))
ax.tick_params(axis="x", rotation=300)
ax.tick_params(axis="y", rotation=80)
plt.show()

# %%
plt.figure(figsize=(10,10))
ax=sns.boxplot(x="Barrio",y="Precio_Millon", data = inmuebles.query("Barrio in @Top_Barrios & Precio_Millon < 2000 " ))
ax.tick_params(axis="x", rotation=300)
ax.tick_params(axis="y", rotation=80)
plt.show()

# %%
datos_crudos = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Identificación (Capítulo A).csv", sep=";",encoding="latin-1")
datos_crudos
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %%
datos_crudos.dtypes
# Out:
# DIRECTORIO          float64
# DPTO                  int64
# MPIO                  int64
# CLASE                 int64
# COD_LOCALIDAD       float64
# NOMBRE_LOCALIDAD     object
# COD_UPZ_GRUPO       float64
# NOMBRE_UPZ_GRUPO     object
# ESTRATO2021           int64
# NOMBRE_ESTRATO       object
# FEX_C                object
# dtype: object

# %%
datos_crudos.info
# Out:
# <bound method DataFrame.info of         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %%
datos_crudos.shape
# Out:
# (106467, 11)

# %%
datos_crudos = datos_crudos.loc[datos_crudos.MPIO == 11001]
datos_crudos.shape
# Out:
# (86504, 11)

# %%
datos_e = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Composición del hogar y demografía (Capítulo E).csv", sep=";",encoding="latin-1")
datos_c = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv", sep=";",encoding="latin-1")
datos_b = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv", sep=";",encoding="latin-1")
datos_h = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Educación (Capítulo H).csv", sep=";",encoding="latin-1")
datos_k = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Fuerza de trabajo (Capítulo K).csv", sep=";",encoding="latin-1")
datos_l = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv", sep=";",encoding="latin-1")
datos_cod_upz = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/cod_upz.csv", sep=";",encoding="latin-1")
# Out:
# <ipython-input-88-e129b804cd8d>:1: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Composición del hogar y demografía (Capítulo E).csv", sep=";",encoding="latin-1")
# <ipython-input-88-e129b804cd8d>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv", sep=";",encoding="latin-1")
# <ipython-input-88-e129b804cd8d>:3: DtypeWarning: Columns (0,1,2,3,4,5,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_b = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv", sep=";",encoding="latin-1")
# ...

# %%
datos_dane = pd.merge(datos_crudos,datos_b,on="DIRECTORIO", how="left")
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on="DIRECTORIO", how="left")
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on="DIRECTORIO", how="left")
datos_dane.shape
# Out:
# <ipython-input-91-bc097691f8fd>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on="DIRECTORIO", how="left")
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(186), int64(73), object(22)
# memory usage: 513.3+ MB

# %% [markdown]
# # CLASE NUMERO 4

# %%
datos_dane = pd.read_csv("/content/drive/MyDrive/Ciencia de Datos/datos_dane.csv")
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...
